# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
"import ho gaya"
# Out:
# 'import ho gaya'

# %%
g7_pop = pd.Series([35.467, 63.951, 80.940, 60.665, 127.061, 64.511, 318.523])

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# dtype: float64

# %%
a = g7_pop
a.name = "jigyasu patel"

# %%
a
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.061
# 5     64.511
# 6    318.523
# Name: jigyasu patel, dtype: float64

# %%
a.values
# Out:
# array([ 35.467,  63.951,  80.94 ,  60.665, 127.061,  64.511, 318.523])

# %%
type(a.values)
# Out:
# numpy.ndarray

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
l = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
a.index = l
a
# Out:
# a     35.467
# b     63.951
# c     80.940
# d     60.665
# e    127.061
# f     64.511
# g    318.523
# Name: jigyasu patel, dtype: float64

# %%
a['a']
# Out:
# 35.467

# %%
a.iloc[0]
# Out:
# 35.467

# %%
a[['a', 'c']]
# Out:
# a    35.467
# c    80.940
# Name: jigyasu patel, dtype: float64

# %%
a.iloc[[1,2,3]]
# Out:
# b    63.951
# c    80.940
# d    60.665
# Name: jigyasu patel, dtype: float64

# %%
a['a':'c']

# %%
a>70

# %%
a[a>70]

# %%
a.mean

# %%
a.mean()

# %%
a[a>a.mean()]

# %%
a.std()

# %%
97+64

# %%
107+97

# %%
a*1000

# %%
a*10000_00

# %%
print(a.mean())
a.std()

# %%
a.mean()

# %%
# a.DataFrame

# %%
a

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
pd

# %%
df

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States',
]

# %%
df

# %%
df.info

# %%
df.describe()

# %%
df.iloc[1]

# %%
df['Population'].to_frame()

# %%
df.iloc[1].to_frame()

# %%
df.loc['France': 'Italy']

# %%
df.loc['France': 'Italy', 'Population'].to_frame()

# %%
df.iloc[1:3, 1:3]

# %%
df.loc[df['Population'] > 100, 'Population'].to_frame()

# %%
df.drop(['Japan', 'France'])

# %%
df.drop(['Japan', 'France'], axis = 0)

# %%
df.drop(['Population', 'HDI'], axis = 1)

# %%
df.rename(index=str.upper)

# %%
df.rename(index=lambda x: x.lower())

# %%
df['Language'] = 'English'
df

# %%
df.drop(columns='Language', inplace=True)

# %%
df

# %%
d = pd.read_csv('C:/Users/avina/Downloads/housepricedata.csv')

# %%
d.head()
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
# 4    14260            8            5         1145         2         1
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0
# 4             4             9           1         836                 1

# %%
d.tail()
# Out:
#       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0

# %%
d.size
# Out:
# 16060

# %%
d.info
# Out:
# <bound method DataFrame.info of       LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0        8450            7            5          856         2         1
# 1        9600            6            8         1262         2         0
# 2       11250            7            5          920         2         1
# 3        9550            7            5          756         1         0
# 4       14260            8            5         1145         2         1
# ...       ...          ...          ...          ...       ...       ...
# 1455     7917            6            5          953         2         1
# 1456    13175            6            6         1542         2         0
# 1457     9042            7            9         1152         2         0
# 1458     9717            5            6         1078         1         0
# 1459     9937            5            6         1256         1         1
#
#       BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0                3             8           0         548                 1
# 1                3             6           1         460                 1
# 2                3             6           1         608                 1
# 3                3             7           1         642                 0
# 4                4             9           1         836                 1
# ...            ...           ...         ...         ...               ...
# 1455             3             7           1         460                 1
# 1456             3             7           2         500                 1
# 1457             4             9           2         252                 1
# 1458             2             5           0         240                 0
# 1459             3             6           0         276                 0
#
# [1460 rows x 11 columns]>

# %%
pd.read_csv?
# Out:
# Object `pd.read_csv` not found.

# %%
d.size
# Out:
# 16060

# %%
d.shape
# Out:
# (1460, 11)

# %%
d.dtypes
# Out:
# LotArea             int64
# OverallQual         int64
# OverallCond         int64
# TotalBsmtSF         int64
# FullBath            int64
# HalfBath            int64
# BedroomAbvGr        int64
# TotRmsAbvGrd        int64
# Fireplaces          int64
# GarageArea          int64
# AboveMedianPrice    int64
# dtype: object

# %%
d.loc[1]
# Out:
# LotArea             9600
# OverallQual            6
# OverallCond            8
# TotalBsmtSF         1262
# FullBath               2
# HalfBath               0
# BedroomAbvGr           3
# TotRmsAbvGrd           6
# Fireplaces             1
# GarageArea           460
# AboveMedianPrice       1
# Name: 1, dtype: int64

# %%
d.head(4)
# Out:
#    LotArea  OverallQual  OverallCond  TotalBsmtSF  FullBath  HalfBath  \
# 0     8450            7            5          856         2         1
# 1     9600            6            8         1262         2         0
# 2    11250            7            5          920         2         1
# 3     9550            7            5          756         1         0
#
#    BedroomAbvGr  TotRmsAbvGrd  Fireplaces  GarageArea  AboveMedianPrice
# 0             3             8           0         548                 1
# 1             3             6           1         460                 1
# 2             3             6           1         608                 1
# 3             3             7           1         642                 0

# %%
d.plot()
# Out:
# <Axes: >

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   LotArea           1460 non-null   int64
#  1   OverallQual       1460 non-null   int64
#  2   OverallCond       1460 non-null   int64
#  3   TotalBsmtSF       1460 non-null   int64
#  4   FullBath          1460 non-null   int64
#  5   HalfBath          1460 non-null   int64
#  6   BedroomAbvGr      1460 non-null   int64
#  7   TotRmsAbvGrd      1460 non-null   int64
#  8   Fireplaces        1460 non-null   int64
#  9   GarageArea        1460 non-null   int64
#  10  AboveMedianPrice  1460 non-null   int64
# dtypes: int64(11)
# memory usage: 125.6 KB

# %%
d.isnull().sum()
# Out:
# LotArea             0
# OverallQual         0
# OverallCond         0
# TotalBsmtSF         0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# TotRmsAbvGrd        0
# Fireplaces          0
# GarageArea          0
# AboveMedianPrice    0
# dtype: int64

# %%
plt.plot(d.index, d['TotalBsmtSF'])

# %%
subset = d.iloc[0:101]

# %%
plt.plot(subset.index, subset['TotalBsmtSF'])

# %%
import seaborn as sns

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      ----- -------------------------------- 41.0/293.3 kB 50.4 kB/s eta 0:00:06
#      ------- ------------------------------ 61.4/293.3 kB 81.9 kB/s eta 0:00:03
#      --------- ---------------------------- 71.7/293.3 kB 89.4 kB/s eta 0:00:03
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/293.3 kB 109.2 kB/s eta 0:00:02
